# %% [markdown]
# <a href="https://colab.research.google.com/github/sanyuan123/LabResources/blob/master/Copy_of_era_boosting_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from xgboost import XGBRegressor
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
TRAINING_DATAPATH = 'https://numerai-public-datasets.s3-us-west-2.amazonaws.com/latest_numerai_training_data.csv.xz'
df = pd.read_csv(TRAINING_DATAPATH)
features = [c for c in df if c.startswith("feature")]

def ar1(x):
    return np.corrcoef(x[:-1], x[1:])[0,1]

def autocorr_penalty(x):
    n = len(x)
    p = ar1(x)
    return np.sqrt(1 + 2*np.sum([((n - i)/n)*p**i for i in range(1,n)]))

def smart_sharpe(x):
    return np.mean(x)/(np.std(x, ddof=1)*autocorr_penalty(x))

def spearmanr(target, pred):
    return np.corrcoef(
        target,
        pred.rank(pct=True, method="first")
    )[0, 1]

def era_boost_train(X, y, era_col, proportion=0.5, trees_per_step=10, num_iters=10):
    model = XGBRegressor(max_depth=5, learning_rate=0.01, n_estimators=trees_per_step, n_jobs=-1, colsample_bytree=0.1)
    features = X.columns
    model.fit(X, y)
    new_df = X.copy()
    new_df["target"] = y
    new_df["era"] = era_col
    for i in range(num_iters-1):
        print(f"iteration {i}")
        # score each era
        print("predicting on train")
        preds = model.predict(X)
        new_df["pred"] = preds
        era_scores = pd.Series(index=new_df["era"].unique())
        print("getting per era scores")
        for era in new_df["era"].unique():
            era_df = new_df[new_df["era"] == era]
            era_scores[era] = spearmanr(era_df["pred"], era_df["target"])
        era_scores.sort_values(inplace=True)
        worst_eras = era_scores[era_scores <= era_scores.quantile(proportion)].index
        print(list(worst_eras))
        worst_df = new_df[new_df["era"].isin(worst_eras)]
        era_scores.sort_index(inplace=True)
        era_scores.plot(kind="bar")
        print("performance over time")
        plt.show()
        print("autocorrelation")
        print(ar1(era_scores))
        print("mean correlation")
        print(np.mean(era_scores))
        print("sharpe")
        print(np.mean(era_scores)/np.std(era_scores))
        print("smart sharpe")
        print(smart_sharpe(era_scores))
        model.n_estimators += trees_per_step
        booster = model.get_booster()
        print("fitting on worst eras")
        model.fit(worst_df[features], worst_df["target"], xgb_model=booster)
    return model

boost_model = era_boost_train(df[features], df["target"], era_col=df["era"], proportion=0.5, trees_per_step=10, num_iters=20)
# Out:
# [04:27:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# iteration 0
# predicting on train
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:39: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# getting per era scores
# ['era68', 'era103', 'era91', 'era60', 'era41', 'era58', 'era74', 'era85', 'era67', 'era66', 'era112', 'era84', 'era107', 'era119', 'era27', 'era59', 'era81', 'era40', 'era24', 'era33', 'era113', 'era100', 'era14', 'era116', 'era101', 'era5', 'era79', 'era117', 'era29', 'era104', 'era69', 'era97', 'era75', 'era106', 'era49', 'era7', 'era35', 'era26', 'era86', 'era28', 'era54', 'era42', 'era110', 'era114', 'era118', 'era34', 'era17', 'era89', 'era18', 'era73', 'era31', 'era15', 'era9', 'era55', 'era57', 'era71', 'era52', 'era50', 'era87', 'era65']
# performance over time
# autocorrelation
# 0.1509811855825418
# mean correlation
# 0.06379870409027674
# sharpe
# 2.385371474123276
# smart sharpe
# 2.04278805941338
# fitting on worst eras
# [04:27:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# iteration 1
# predicting on train
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:39: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# getting per era scores
# ['era80', 'era4', 'era56', 'era120', 'era3', 'era30', 'era43', 'era25', 'era99', 'era105', 'era45', 'era19', 'era8', 'era91', 'era11', 'era48', 'era37', 'era6', 'era93', 'era51', 'era108', 'era102', 'era2', 'era10', 'era13', 'era12', 'era78', 'era23', 'era47', 'era32', 'era72', 'era82', 'era109', 'era46', 'era88', 'era70', 'era115', 'era90', 'era77', 'era94', 'era95', 'era111', 'era16', 'era29', 'era98', 'era44', 'era41', 'era74', 'era22', 'era38', 'era61', 'era103', 'era62', 'era36', 'era21', 'era96', 'era85', 'era83', 'era28', 'era64']
# performance over time
# autocorrelation
# -0.0583421493182675
# mean correlation
# 0.07207667808324243
# sharpe
# 2.5740252409220723
# smart sharpe
# 2.716128886482323
# fitting on worst eras
# [04:28:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# iteration 2
# predicting on train
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:39: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# getting per era scores
# ['era68', 'era58', 'era60', 'era107', 'era69', 'era104', 'era103', 'era112', 'era106', 'era119', 'era116', 'era113', 'era91', 'era50', 'era73', 'era89', 'era67', 'era84', 'era100', 'era110', 'era79', 'era66', 'era101', 'era59', 'era27', 'era17', 'era9', 'era53', 'era54', 'era33', 'era41', 'era117', 'era34', 'era87', 'era114', 'era42', 'era7', 'era40', 'era85', 'era49', 'era18', 'era65', 'era3', 'era31', 'era15', 'era80', 'era26', 'era81', 'era24', 'era1', 'era75', 'era55', 'era57', 'era97', 'era14', 'era35', 'era21', 'era70', 'era118', 'era111']
# performance over time
# autocorrelation
# 0.02404617124481431
# mean correlation
# 0.07868144290381571
# sharpe
# 2.3724074161860895
# smart sharpe
# 2.3068220365403604
# fitting on worst eras
# [04:28:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# iteration 3
# predicting on train
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:39: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# getting per era scores
# ['era68', 'era58', 'era100', 'era91', 'era3', 'era25', 'era86', 'era71', 'era78', 'era34', 'era79', 'era20', 'era99', 'era60', 'era56', 'era74', 'era19', 'era116', 'era5', 'era119', 'era29', 'era46', 'era2', 'era63', 'era93', 'era32', 'era84', 'era114', 'era117', 'era6', 'era9', 'era37', 'era102', 'era107', 'era112', 'era103', 'era28', 'era89', 'era106', 'era85', 'era77', 'era98', 'era80', 'era4', 'era44', 'era76', 'era12', 'era43', 'era81', 'era66', 'era67', 'era82', 'era120', 'era52', 'era94', 'era41', 'era73', 'era88', 'era13', 'era36']
# performance over time
# autocorrelation
# -0.09637299128798481
# mean correlation
# 0.08896377562813867
# sharpe
# 5.950678296248116
# smart sharpe
# 6.522019939888391
# fitting on worst eras
# [04:28:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# iteration 4
# predicting on train
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:39: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# getting per era scores
# ['era68', 'era59', 'era65', 'era31', 'era69', 'era53', 'era104', 'era75', 'era113', 'era58', 'era27', 'era49', 'era33', 'era50', 'era18', 'era57', 'era62', 'era48', 'era35', 'era40', 'era42', 'era14', 'era91', 'era24', 'era11', 'era110', 'era54', 'era97', 'era118', 'era96', 'era17', 'era26', 'era25', 'era21', 'era39', 'era60', 'era103', 'era116', 'era106', 'era100', 'era45', 'era47', 'era117', 'era101', 'era72', 'era41', 'era10', 'era70', 'era119', 'era87', 'era61', 'era3', 'era16', 'era7', 'era51', 'era107', 'era109', 'era5', 'era9', 'era15']
# performance over time
# autocorrelation
# -0.045710461641951534
# mean correlation
# 0.09647328745661604
# sharpe
# 6.226855280667331
# smart sharpe
# 6.488608337085414
# fitting on worst eras
# [04:29:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# iteration 5
# predicting on train
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:39: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# getting per era scores
# ['era34', 'era74', 'era112', 'era85', 'era84', 'era19', 'era66', 'era8', 'era22', 'era108', 'era68', 'era86', 'era114', 'era71', 'era90', 'era79', 'era28', 'era55', 'era67', 'era78', 'era80', 'era81', 'era99', 'era29', 'era56', 'era37', 'era77', 'era46', 'era2', 'era115', 'era98', 'era91', 'era102', 'era105', 'era94', 'era89', 'era59', 'era30', 'era32', 'era44', 'era35', 'era83', 'era4', 'era113', 'era43', 'era73', 'era6', 'era82', 'era111', 'era93', 'era95', 'era38', 'era12', 'era42', 'era52', 'era20', 'era31', 'era92', 'era23', 'era14']
# performance over time
# autocorrelation
# 0.2188171242209309
# mean correlation
# 0.09790862578009224
# sharpe
# 7.063017493421817
# smart sharpe
# 5.64174653423976
# fitting on worst eras
# [04:29:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# iteration 6
# predicting on train
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:39: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# getting per era scores
# ['era69', 'era58', 'era103', 'era107', 'era68', 'era104', 'era41', 'era91', 'era50', 'era60', 'era65', 'era9', 'era110', 'era27', 'era33', 'era21', 'era112', 'era116', 'era18', 'era106', 'era40', 'era85', 'era119', 'era53', 'era57', 'era49', 'era26', 'era54', 'era62', 'era15', 'era117', 'era3', 'era87', 'era101', 'era7', 'era70', 'era25', 'era88', 'era100', 'era34', 'era97', 'era75', 'era24', 'era46', 'era48', 'era118', 'era13', 'era59', 'era81', 'era17', 'era89', 'era1', 'era64', 'era84', 'era73', 'era102', 'era67', 'era111', 'era32', 'era10']
# performance over time
# autocorrelation
# -0.028861141129303436
# mean correlation
# 0.10184929252110168
# sharpe
# 5.020468893543202
# smart sharpe
# 5.1447033828372115
# fitting on worst eras
# [04:30:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# iteration 7
# predicting on train
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:39: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# getting per era scores
# ['era66', 'era79', 'era74', 'era114', 'era28', 'era45', 'era120', 'era80', 'era36', 'era51', 'era56', 'era19', 'era96', 'era63', 'era29', 'era34', 'era41', 'era35', 'era108', 'era11', 'era93', 'era55', 'era3', 'era91', 'era78', 'era109', 'era9', 'era76', 'era8', 'era103', 'era71', 'era22', 'era31', 'era98', 'era2', 'era100', 'era58', 'era113', 'era43', 'era86', 'era99', 'era90', 'era77', 'era61', 'era116', 'era72', 'era42', 'era68', 'era85', 'era14', 'era30', 'era47', 'era37', 'era118', 'era21', 'era117', 'era39', 'era65', 'era94', 'era16']
# performance over time
# autocorrelation
# -0.02728869457548943
# mean correlation
# 0.10794117903815134
# sharpe
# 8.903474029020579
# smart sharpe
# 9.109568675809086
# fitting on worst eras
# [04:31:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# iteration 8
# predicting on train
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:39: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# getting per era scores
# ['era69', 'era107', 'era60', 'era68', 'era106', 'era50', 'era33', 'era119', 'era112', 'era104', 'era27', 'era57', 'era18', 'era40', 'era58', 'era84', 'era110', 'era87', 'era53', 'era103', 'era70', 'era44', 'era91', 'era81', 'era41', 'era75', 'era49', 'era82', 'era46', 'era59', 'era67', 'era52', 'era54', 'era5', 'era24', 'era15', 'era26', 'era7', 'era89', 'era17', 'era62', 'era25', 'era101', 'era88', 'era73', 'era111', 'era116', 'era9', 'era38', 'era66', 'era6', 'era97', 'era102', 'era12', 'era117', 'era85', 'era32', 'era42', 'era31', 'era113']
# performance over time
# autocorrelation
# 0.064198229875203
# mean correlation
# 0.11310824970024085
# sharpe
# 6.948868037665919
# smart sharpe
# 6.492485900172383
# fitting on worst eras
# [04:31:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# iteration 9
# predicting on train
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:39: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# getting per era scores
# ['era34', 'era114', 'era4', 'era28', 'era35', 'era79', 'era105', 'era29', 'era80', 'era3', 'era45', 'era19', 'era74', 'era100', 'era51', 'era83', 'era63', 'era56', 'era36', 'era115', 'era95', 'era11', 'era71', 'era48', 'era96', 'era98', 'era109', 'era21', 'era86', 'era8', 'era12', 'era99', 'era120', 'era118', 'era78', 'era65', 'era55', 'era37', 'era13', 'era93', 'era57', 'era64', 'era22', 'era108', 'era2', 'era16', 'era90', 'era20', 'era112', 'era94', 'era25', 'era84', 'era14', 'era92', 'era107', 'era43', 'era60', 'era72', 'era47', 'era75']
# performance over time
# autocorrelation
# 0.1439808790671725
# mean correlation
# 0.11913566935216909
# sharpe
# 9.99606118532752
# smart sharpe
# 8.621381866244972
# fitting on worst eras
# [04:32:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# iteration 10
# predicting on train
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:39: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# getting per era scores
# ['era68', 'era69', 'era103', 'era58', 'era91', 'era104', 'era33', 'era119', 'era50', 'era106', 'era27', 'era107', 'era41', 'era110', 'era40', 'era59', 'era87', 'era18', 'era116', 'era60', 'era111', 'era89', 'era70', 'era62', 'era53', 'era46', 'era85', 'era82', 'era1', 'era26', 'era54', 'era17', 'era9', 'era88', 'era73', 'era101', 'era67', 'era81', 'era15', 'era24', 'era39', 'era117', 'era10', 'era113', 'era32', 'era7', 'era42', 'era112', 'era65', 'era44', 'era52', 'era21', 'era102', 'era49', 'era66', 'era114', 'era77', 'era97', 'era57', 'era38']
# performance over time
# autocorrelation
# 0.029839948871873696
# mean correlation
# 0.1196430421342267
# sharpe
# 5.645645764584002
# smart sharpe
# 5.458099223430573
# fitting on worst eras
# [04:33:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# iteration 11
# predicting on train
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:39: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# getting per era scores
# ['era3', 'era34', 'era79', 'era6', 'era5', 'era28', 'era19', 'era80', 'era29', 'era4', 'era35', 'era100', 'era91', 'era56', 'era23', 'era51', 'era61', 'era74', 'era30', 'era119', 'era93', 'era76', 'era11', 'era45', 'era68', 'era2', 'era31', 'era12', 'era84', 'era98', 'era36', 'era78', 'era94', 'era86', 'era87', 'era118', 'era85', 'era71', 'era41', 'era96', 'era46', 'era13', 'era103', 'era55', 'era25', 'era63', 'era115', 'era48', 'era99', 'era14', 'era67', 'era44', 'era109', 'era117', 'era114', 'era33', 'era90', 'era40', 'era120', 'era72']
# performance over time
# autocorrelation
# 0.08606973942179916
# mean correlation
# 0.12817481032304082
# sharpe
# 12.436492720568895
# smart sharpe
# 11.369006064691193
# fitting on worst eras
# [04:34:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# iteration 12
# predicting on train
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:39: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# getting per era scores
# ['era69', 'era58', 'era50', 'era107', 'era111', 'era106', 'era104', 'era59', 'era68', 'era110', 'era60', 'era27', 'era116', 'era70', 'era81', 'era1', 'era26', 'era7', 'era18', 'era17', 'era53', 'era65', 'era9', 'era62', 'era103', 'era21', 'era73', 'era91', 'era16', 'era82', 'era54', 'era24', 'era47', 'era112', 'era57', 'era10', 'era39', 'era89', 'era77', 'era113', 'era42', 'era49', 'era34', 'era97', 'era83', 'era32', 'era75', 'era101', 'era15', 'era43', 'era56', 'era37', 'era102', 'era88', 'era5', 'era3', 'era66', 'era31', 'era33', 'era40']
# performance over time
# autocorrelation
# 0.07781630404520103
# mean correlation
# 0.1351458934740358
# sharpe
# 8.714824117123294
# smart sharpe
# 8.032696476976579
# fitting on worst eras
# [04:35:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# iteration 13
# predicting on train
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:39: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# getting per era scores
# ['era95', 'era105', 'era108', 'era22', 'era8', 'era29', 'era79', 'era4', 'era35', 'era119', 'era28', 'era51', 'era19', 'era6', 'era64', 'era100', 'era80', 'era12', 'era87', 'era11', 'era84', 'era36', 'era114', 'era117', 'era2', 'era46', 'era98', 'era94', 'era30', 'era20', 'era86', 'era41', 'era92', 'era93', 'era34', 'era85', 'era52', 'era45', 'era14', 'era67', 'era61', 'era13', 'era74', 'era23', 'era99', 'era118', 'era78', 'era7', 'era25', 'era44', 'era96', 'era48', 'era63', 'era55', 'era38', 'era75', 'era60', 'era76', 'era72', 'era59']
# performance over time
# autocorrelation
# 0.12276198657911043
# mean correlation
# 0.14121913650186826
# sharpe
# 12.649996180798725
# smart sharpe
# 11.146529790020598
# fitting on worst eras
# [04:36:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# iteration 14
# predicting on train
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:39: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# getting per era scores
# ['era69', 'era58', 'era68', 'era107', 'era106', 'era111', 'era103', 'era104', 'era70', 'era116', 'era50', 'era91', 'era110', 'era27', 'era21', 'era9', 'era65', 'era54', 'era26', 'era73', 'era1', 'era17', 'era81', 'era112', 'era62', 'era53', 'era18', 'era82', 'era56', 'era57', 'era113', 'era16', 'era89', 'era40', 'era97', 'era33', 'era42', 'era24', 'era101', 'era15', 'era32', 'era41', 'era47', 'era10', 'era39', 'era77', 'era3', 'era88', 'era102', 'era43', 'era37', 'era60', 'era7', 'era29', 'era59', 'era66', 'era31', 'era49', 'era87', 'era117']
# performance over time
# autocorrelation
# 0.08230964522286222
# mean correlation
# 0.14463227995835137
# sharpe
# 8.004804643649521
# smart sharpe
# 7.345240871481097
# fitting on worst eras
# [04:38:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# iteration 15
# predicting on train
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:39: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# getting per era scores
# ['era71', 'era90', 'era109', 'era108', 'era83', 'era105', 'era79', 'era22', 'era51', 'era35', 'era12', 'era6', 'era115', 'era119', 'era28', 'era19', 'era8', 'era98', 'era4', 'era34', 'era120', 'era5', 'era95', 'era114', 'era100', 'era2', 'era84', 'era85', 'era86', 'era67', 'era36', 'era52', 'era46', 'era80', 'era64', 'era48', 'era93', 'era99', 'era94', 'era74', 'era11', 'era20', 'era44', 'era118', 'era45', 'era25', 'era13', 'era30', 'era75', 'era55', 'era21', 'era61', 'era96', 'era3', 'era63', 'era23', 'era70', 'era14', 'era68', 'era72']
# performance over time
# autocorrelation
# 0.12627592107045046
# mean correlation
# 0.1534886288618423
# sharpe
# 13.635940779441794
# smart sharpe
# 11.972852361605648
# fitting on worst eras
# [04:39:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# iteration 16
# predicting on train
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:39: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# getting per era scores
# ['era69', 'era58', 'era107', 'era103', 'era91', 'era104', 'era111', 'era50', 'era106', 'era116', 'era27', 'era9', 'era110', 'era65', 'era1', 'era54', 'era81', 'era40', 'era68', 'era62', 'era73', 'era82', 'era17', 'era26', 'era112', 'era18', 'era53', 'era57', 'era89', 'era41', 'era56', 'era32', 'era60', 'era42', 'era33', 'era38', 'era16', 'era101', 'era39', 'era97', 'era59', 'era113', 'era117', 'era70', 'era7', 'era15', 'era10', 'era102', 'era87', 'era88', 'era43', 'era47', 'era77', 'era29', 'era24', 'era21', 'era37', 'era2', 'era31', 'era49']
# performance over time
# autocorrelation
# 0.08751331128733407
# mean correlation
# 0.1560571929553081
# sharpe
# 7.849418096277833
# smart sharpe
# 7.165321779191353
# fitting on worst eras
# [04:41:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# iteration 17
# predicting on train
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:39: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# getting per era scores
# ['era78', 'era66', 'era34', 'era79', 'era76', 'era12', 'era51', 'era19', 'era114', 'era90', 'era119', 'era71', 'era35', 'era28', 'era108', 'era6', 'era98', 'era92', 'era4', 'era93', 'era22', 'era85', 'era46', 'era109', 'era100', 'era67', 'era80', 'era83', 'era11', 'era36', 'era84', 'era44', 'era95', 'era120', 'era115', 'era105', 'era5', 'era99', 'era52', 'era94', 'era3', 'era64', 'era75', 'era8', 'era48', 'era14', 'era63', 'era61', 'era30', 'era86', 'era118', 'era69', 'era43', 'era25', 'era111', 'era45', 'era107', 'era58', 'era96', 'era91']
# performance over time
# autocorrelation
# 0.05100496655901657
# mean correlation
# 0.1661784669163418
# sharpe
# 15.955965984127152
# smart sharpe
# 15.104998921412726
# fitting on worst eras
# [04:42:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# iteration 18
# predicting on train
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:39: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# getting per era scores
# ['era103', 'era27', 'era104', 'era69', 'era68', 'era50', 'era106', 'era116', 'era58', 'era9', 'era40', 'era73', 'era18', 'era65', 'era57', 'era54', 'era112', 'era60', 'era62', 'era26', 'era41', 'era110', 'era17', 'era32', 'era42', 'era1', 'era81', 'era82', 'era15', 'era33', 'era117', 'era101', 'era56', 'era55', 'era13', 'era10', 'era7', 'era29', 'era53', 'era70', 'era59', 'era113', 'era21', 'era20', 'era107', 'era39', 'era16', 'era2', 'era89', 'era77', 'era91', 'era111', 'era87', 'era47', 'era97', 'era102', 'era38', 'era24', 'era88', 'era119']
# performance over time
# autocorrelation
# 0.037050044706025735
# mean correlation
# 0.16965068888804116
# sharpe
# 9.722703338515053
# smart sharpe
# 9.332676415740059
# fitting on worst eras
# [04:44:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.

# %%
model=boost_model.fit(df[features], df["target"])
# Out:
# [04:53:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.

# %%
preds = model.predict(df[features])

# %%
len(preds)
# Out:
# 501808

# %%
model.score()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-48a6c01e0773> in <module>()
# ----> 1 model.score()
#
# TypeError: score() missing 2 required positional arguments: 'X' and 'y'
